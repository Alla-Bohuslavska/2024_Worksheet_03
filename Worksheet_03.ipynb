# %% [markdown]
# ## Statistics 2780A - Statistical Inference ##
# ## Fall 2024 #
# ## Tutorial 3 #
# September 25, 2024

# %% [markdown]
# ## Q1 ##
# 1. Compute the following quantiles of Student's T distribution:
#    1. 95th quantile of T distribution with 5 degrees of freedom;
#    2. 99th quantile of T distribution with 7 degrees of freedom;
#    3. 90th quantile of T distribution with 10 degrees of freedom;
#    4. 10th quantile of T distribution with 10 degrees of freedom.
#
#    What do you observe about the quantiles computed in C. and D. Justify your answer.
#
#    Compute the following probabilities of a random variable $T$, Student's T distributed:
#
#    1. $P(T\leq 1.5)$, where $T\sim t_{10}$;
#    2. $P(T\leq -0.75)$, where $T\sim t_{20}$;
#    3. $P(T\leq 0.83)$, where $T\sim t_4$;

# %%
# answer

# %% [markdown]
# ## Q2 ##
# 2. Consider the dataset $\texttt{airquality}$ in the R package $\texttt{datasets}$. It consists of several variables measuring the air quality in New York, from May to September 1973.
#    We focus on variable $\texttt{Temp}$ in June, whose observations can be selected using the following command:
#    `x<-  airquality$Temp[airquality$Month==6]`
#
#     We assume that the data is generated by a normal distribution.
#     1. Assume that the standard deviation is known and it is equal to 15 (degrees F).
#         1. Compute the sample mean of the observations.
#         2. Determine an estimate 95% confidence interval for the unknown mean $\mu$ based on the sample. What is the value of the quantile that we use for this construction?
#         3. Determine an estimate 85% confidence interval for $\mu$. What do you observe between the intervals in A.b and A.c?
#     2. Estimate the value of the standard deviation using the sample standard deviation estimator.
#        1. Compute the same two confidence intervals from A.b and A.c.

# %%
# answer

# %% [markdown]
# ## Q3 ##
# 3. The measurement errors of an instrument are assumed to be normally distributed with unknown mean and standard deviation $\sigma = 3$ cm. 10 randomly selected devices are selected and their lengths (in cm) are measured with the instrument and compared with the prototype.
#
#    The following sample is obtained:
#
#    `x <- c(6.44, 10.59, 10.15,  8.90,  4.76,  5.47,  3.03, -0.99,  9.30,  4.08)`
#
#    Compute an estimated $(1-\alpha)\%$ confidence interval for the true mean error $\mu$ at the following levels
#    1. $\alpha=0.1$
#    2. $\alpha=0.05$
#    3. $\alpha=0.01$
#
#    What do you observe about the lengths of intervals when $\alpha$ decreases, i.e., $1-\alpha$ increases?
#
#    We consider that the sample is too small and we randomly select 20 devices and obtained the following measurement errors:
#
#    `y <- c(7.39, -3.14,  0.82,  6.81,  6.56,  8.38, -0.24,  5.70,  5.75,  0.08,  2.38,  9.84,  4.16,  5.05,  1.99,  4.83,  6.07,  6.47, 10.44, -3.04)`
#
#    Compute an estimated $95\%$ confidence interval for the true mean error $\mu$ using the sample $y$. Compare the result with the $95\%$ confidence interval for $\mu$ using the sample $x$. What do you observe?

# %%
# answer
